# %% [markdown]
# <a href="https://colab.research.google.com/github/MaddyMk05/VA_Open_Ended_Experiments/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy
import pandas as pd
import plotly.express as px
import geopandas as gpd
import folium
from folium import Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
factories = gpd.read_file('/content/factoriesindustrial-sites.geojson')
factories.head()
# Out:
#                                   id state_code source  \
# 0   u_fc_poi_factory_industry_site.1         LA   GRID
# 1   u_fc_poi_factory_industry_site.2         LA   GRID
# 2   u_fc_poi_factory_industry_site.4         LA   GRID
# 3  u_fc_poi_factory_industry_site.11         LA   GRID
# 4  u_fc_poi_factory_industry_site.18         LA   GRID
#
#                               name  status ward_code  \
# 0  JJ International Block Industry  In Use  LASIUI05
# 1            Kadiri Block Industry  In Use  LASIUI04
# 2                      Teju Blocks  In Use  LASIKU29
# 3      Adurumigba Block Industries  In Use  LASBDY08
# 4                Abllat Nig Co Ltd  In Use  LASAMO24
#
#                               global_id                 geometry
# 0  000b39d0-ba96-4d62-91f3-52bef3d64890  POINT (3.78227 6.47244)
# 1  001a5124-6f66-457f-ac1b-c4f1fde6a61a   POINT (3.68407 6.4609)
# 2  004d7b39-d3b8-4074-b270-d0fc09a20510  POINT (3.54362 6.59287)
# 3  006bb17c-b0fc-4b09-acc4-59250acdcfce  POINT (3.03417 6.46336)
# 4  0097ec77-7a51-44a4-a83d-c15f67e03fad   POINT (3.25955 6.5269)

# %%
factories.columns.to_list()
factories = factories[['name', 'status', 'geometry']]
factories['lon'] = factories.geometry.apply(lambda p: p.x)
factories['lat'] = factories.geometry.apply(lambda p: p.y)
# Out:
# /usr/local/lib/python3.11/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from IPython.display import display

# Create folium map with markers
mark = folium.Map(location=[6.5244, 3.3792], tiles='cartodbpositron', zoom_start=10)
for idx, row in factories.iterrows():
    Marker([row['lat'], row['lon']], popup=row['name']).add_to(mark)
display(mark)  # 👈 Use this instead of just `mark`

# MarkerCluster map
bubble = folium.Map(location=[6.5244, 3.3792], zoom_start=12, tiles='cartodbpositron')
mc = MarkerCluster()
for idx, row in factories.iterrows():
    mc.add_child(Marker([row['lat'], row['lon']]))
bubble.add_child(mc)
display(bubble)  # 👈 Use this instead of just `bubble`

# HeatMap
heat = folium.Map(location=[6.5244, 3.3792], tiles='cartodbpositron', zoom_start=10)
HeatMap(data=factories[['lat', 'lon']], radius=10).add_to(heat)
display(heat)  # 👈 Use this instead of just `heat`
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01d020ef34080e316df66970a5de6d77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01d020ef34080e316df66970a5de6d77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01d020ef34080e316df66970a5de6d77 = L.map(
#                 &quot;map_01d020ef34080e316df66970a5de6d77&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d027caa9e56d51de75265685a925757 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d027caa9e56d51de75265685a925757.addTo(map_01d020ef34080e316df66970a5de6d77);
#
#
#             var marker_d95d21e0385e561bebb10a6da00acb83 = L.marker(
#                 [6.4724391, 3.7822694],
#                 {
# }
#             ).addTo(map_01d020ef34080e316df66970a5de6d77);
#
#
#         var popup_2c9551bea6780423aa6e862cd3d658e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73e348efed50211b10f5dc8023d814a3 = $(`&lt;div id=&quot;html_73e348efed50211b10f5dc8023d814a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JJ International Block Industry&lt;/div&gt;`)[0];
#                 popup_2c9551bea6780423aa6e862cd3d658e8.setContent(html_73e348efed50211b10f5dc8023d814a3);
#
#
#
#         marker_d95d21e0385e561bebb10a6da00acb83.bindPopup(popup_2c9551bea6780423aa6e862cd3d658e8)
#         ;
#
#
#
#
#             var marker_9d52ba64b6f44515e9158d3b2f89dd40 = L.marker(
#                 [6.4609044, 3.6840657],
#                 {
# }
#             ).addTo(map_01d020ef34080e316df66970a5de6d77);
#
#
#         var popup_d8e44562df6bea81ca5def7b406db2e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99615fd69fb0898daaf3a7c63bdcc6d3 = $(`&lt;div id=&quot;html_99615fd69fb0898daaf3a7c63bdcc6d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kadiri Block Industry&lt;/div&gt;`)[0];
#                 popup_d8e44562df6bea81ca5def7b406db2e0.setContent(html_99615fd69fb0898daaf3a7c63bdcc6d3);
#
#
#
#         marker_9d52ba64b6f44515e9158d3b2f89dd40.bindPopup(popup_d8e44562df6bea81ca5def7b406db2e0)
#         ;
#
#
#
#
#             var marker_4a5ac1bc4fd247fec00e5747e3d2a267 = L.marker(
#                 [6.59287, 3.5436183],
#                 {
# }
#             ).addTo(map_01d020ef34080e316df66970a5de6d77);
#
#
#         var popup_cc23bbf7a1d4f74909e562f73ac9d13b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53bd49e62e210c267b4a2cc920dda0c3 = $(`&lt;div id=&quot;html_53bd49e62e210c267b4a2cc920dda0c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Teju Blocks&lt;/div&gt;`)[0];
#                 popup_cc23bbf7a1d4f74909e562f73ac9d13b.setContent(html_53bd49e62e210c267b4a2cc920dda0c3);
#
#
#
#         marker_4a5ac1bc4fd247fec00e5747e3d2a267.bindPopup(popup_cc23bbf7a1d4f74909e562f73ac9d13b)
#         ;
#
#
#
#
#             var marker_31d99ebc97033198de8e73334abb96e9 = L.marker(
#                 [6.4633558, 3.0341748],
#                 {
# }
#             ).addTo(map_01d020ef34080e316df66970a5de6d77);
#
#
#         var popup_4e2046099595664ced3ab7c061192711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff125b994be3f67b369ef2aa82e0e454 = $(`&lt;div id=&quot;html_ff125b994be3f67b369ef2aa82e0e454&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adurumigba Block Industries&lt;/div&gt;`)[0];
#                 popup_4e2046099595664ced3ab7c061192711.setContent(html_ff125b994be3f67b369ef2aa82e0e454);
#
#
#
#         marker_31d99ebc97033198de8e73334abb96e9.bindPopup(popup_4e2046099595664ced3ab7c061192711)
#         ;
#
#
#
#
#             var marker_2639b31406a3b3d462b1005cccf4eded = L.marker(
#                 [6.526905, 3.2595483],
#                 {
# }
#             ).addTo(map_01d020ef34080e316df66970a5de6d77);
#
#
#         var popup_d4cfec5a528e75f738661880594ff727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25e107b0388c38d895810d47bbe2723a = $(`&lt;div id=&quot;html_25e107b0388c38d895810d47bbe2723a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abllat Nig Co Ltd&lt;/div&gt;`)[0];
#                 popup_d4cfec5a528e75f738661880594ff727.setContent(html_25e107b0388c38d895810d47bbe2723a);
#
#
#
#         marker_2639b31406a3b3d462b1005cccf4eded.bindPopup(popup_d4cfec5a528e75f738661880594ff727)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08907c5f5fef6e65e07e6d204a65035d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08907c5f5fef6e65e07e6d204a65035d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08907c5f5fef6e65e07e6d204a65035d = L.map(
#                 &quot;map_08907c5f5fef6e65e07e6d204a65035d&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ac32a1cc301a85a3a22f434d4d4ec9b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ac32a1cc301a85a3a22f434d4d4ec9b.addTo(map_08907c5f5fef6e65e07e6d204a65035d);
#
#
#             var marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_671a8a8e0f9128be05cba47011f4dee9 = L.marker(
#                 [6.4724391, 3.7822694],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_e9594e07af4824fbc8c3d6618ed5255b = L.marker(
#                 [6.4609044, 3.6840657],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_e8e18c592ec82fe0571b02f3ec5e2981 = L.marker(
#                 [6.59287, 3.5436183],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_47e349e2249f2e5363fde0d848b3c227 = L.marker(
#                 [6.4633558, 3.0341748],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_04142efc01315d93cb9d139b6c1e40e4 = L.marker(
#                 [6.526905, 3.2595483],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_a0755c99169faef1269322edc7c78637 = L.marker(
#                 [6.6786892, 3.4940271],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_14c3646a53176eaee671e2be8b5cb291 = L.marker(
#                 [6.5280467, 3.2797783],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_1ccb859d7d63138c5ddef761f01aefd4 = L.marker(
#                 [6.5861481, 3.4884096],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_934d4995d17d8e8a4d485adcb22d75f3 = L.marker(
#                 [6.6600383, 3.3341333],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_9ce6f1bba99c400362704992097bb9db = L.marker(
#                 [6.6537608, 3.5471293],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_49167efd6f4f3884768814293d5083c3 = L.marker(
#                 [6.6570728, 3.5844349],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_0d9f83a542449764fb7c7d1909c54c86 = L.marker(
#                 [6.6675921, 3.5287173],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_cbcad1c9cccbd88c0f5409aa50adfb21 = L.marker(
#                 [6.5207974, 3.2479046],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_50b02db4d4a47680496ed63d555c202a = L.marker(
#                 [6.475655, 3.8459144],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_566dcdd3749f4f7e89fedcd4fcf8f4c2 = L.marker(
#                 [6.4116961, 4.1253959],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_8cdd3b7d24dafb5028961731ac6f5fe7 = L.marker(
#                 [6.6224475, 3.3459393],
#                 {
# }
#             ).addTo(marker_cluster_2cde89fc781ea3dbbb6d6af4d28a3683);
#
#
#             var marker_7d58f063299b73a
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c15f9334aeb4bc830cfacc349481ded {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c15f9334aeb4bc830cfacc349481ded&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c15f9334aeb4bc830cfacc349481ded = L.map(
#                 &quot;map_8c15f9334aeb4bc830cfacc349481ded&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7522598d985c1a0f157c74fdfe88940e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7522598d985c1a0f157c74fdfe88940e.addTo(map_8c15f9334aeb4bc830cfacc349481ded);
#
#
#             var heat_map_5c869e214198e5ff993aa37a474473d3 = L.heatLayer(
#                 [[6.4724391, 3.7822694], [6.4609044, 3.6840657], [6.59287, 3.5436183], [6.4633558, 3.0341748], [6.526905, 3.2595483], [6.6786892, 3.4940271], [6.5280467, 3.2797783], [6.5861481, 3.4884096], [6.6600383, 3.3341333], [6.6537608, 3.5471293], [6.6570728, 3.5844349], [6.6675921, 3.5287173], [6.5207974, 3.2479046], [6.475655, 3.8459144], [6.4116961, 4.1253959], [6.6224475, 3.3459393], [6.438055, 3.3629133], [6.4690936, 3.7540898], [6.4211283, 4.0639683], [6.4636307, 3.6717089], [6.473822, 3.3223893], [6.615114, 3.6450411], [6.4758176, 3.7700664], [6.61151, 3.3673881], [6.4652846, 3.6682425], [6.4636235, 3.7074939], [6.6281034, 3.2538021], [6.623906, 3.2579501], [6.4471279, 3.3633999], [6.6285321, 3.3508418], [6.5096881, 3.2584812], [6.5897372, 3.6565878], [6.5823762, 3.3046987], [6.5541234, 3.3544045], [6.4123717, 4.1168533], [6.4747587, 3.3176446], [6.613868, 3.2555425], [6.4801467, 3.8529733], [6.5792205, 3.2071543], [6.671387, 3.5271126], [6.5694082, 3.5482144], [6.6531392, 3.2611436], [6.4481941, 3.4843224], [6.461315, 3.3387967], [6.4684361, 3.3253575], [6.4780947, 3.8423195], [6.6045032, 3.368434], [6.5974119, 3.5673449], [6.4615363, 3.673053], [6.4590916, 3.