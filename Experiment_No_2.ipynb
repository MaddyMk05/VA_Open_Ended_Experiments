# %% [markdown]
# <a href="https://colab.research.google.com/github/MaddyMk05/VA_Open_Ended_Experiments/blob/main/Experiment_No_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Open-Ended Experiment 2: Geospatial Storytelling with Plotly or Tableau**
#
# **Title:** Visualizing the World: Geospatial Insights from a Global Dataset
#
# **Objective:**
#
# Students will build a geospatial dashboard or visual story using Plotly or Tableau to illustrate a global trend, comparison, or issue.
#
# **Task:**
# 1.   Select a dataset with geospatial information (e.g., global population, COVID-19 cases, renewable energy usage, etc.).
# 2.   Design at least two different types of map visualizations (e.g., choropleth + bubble map).
# 3. Integrate filters or sliders to make it interactive (e.g., year, region).
# 4. Provide a visual story or dashboard that narrates the insight.
#
# **Expected Outcome:**
#
# An interactive report or dashboard published/shared via Tableau Public or a Plotly HTML file.

# %%
import math
import numpy
import pandas as pd
import plotly.express as px
import geopandas as gpd
import folium
from folium import Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
factories = gpd.read_file('/content/factoriesindustrial-sites.geojson')
factories.head()
# Out:
#                                   id state_code source  \
# 0   u_fc_poi_factory_industry_site.1         LA   GRID
# 1   u_fc_poi_factory_industry_site.2         LA   GRID
# 2   u_fc_poi_factory_industry_site.4         LA   GRID
# 3  u_fc_poi_factory_industry_site.11         LA   GRID
# 4  u_fc_poi_factory_industry_site.18         LA   GRID
#
#                               name  status ward_code  \
# 0  JJ International Block Industry  In Use  LASIUI05
# 1            Kadiri Block Industry  In Use  LASIUI04
# 2                      Teju Blocks  In Use  LASIKU29
# 3      Adurumigba Block Industries  In Use  LASBDY08
# 4                Abllat Nig Co Ltd  In Use  LASAMO24
#
#                               global_id                 geometry
# 0  000b39d0-ba96-4d62-91f3-52bef3d64890  POINT (3.78227 6.47244)
# 1  001a5124-6f66-457f-ac1b-c4f1fde6a61a   POINT (3.68407 6.4609)
# 2  004d7b39-d3b8-4074-b270-d0fc09a20510  POINT (3.54362 6.59287)
# 3  006bb17c-b0fc-4b09-acc4-59250acdcfce  POINT (3.03417 6.46336)
# 4  0097ec77-7a51-44a4-a83d-c15f67e03fad   POINT (3.25955 6.5269)

# %%
factories.columns.to_list()
# Out:
# ['id',
#  'state_code',
#  'source',
#  'name',
#  'status',
#  'ward_code',
#  'global_id',
#  'geometry']

# %%
factories = factories[['name', 'status', 'geometry']]

# %%
factories['lon'] = factories.geometry.apply(lambda p: p.x)
factories['lat'] = factories.geometry.apply(lambda p: p.y)

# %%
px.scatter(factories, 'lon', 'lat',
           title='A Scatter Plot of the Latitude and  Longitude of Factories in Lagos'
          )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="36a6c751-f482-4ae1-bd36-93924fc77445" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36a6c751-f482-4ae1-bd36-93924fc77445")) {                    Plotly.newPlot(                        "36a6c751-f482-4ae1-bd36-93924fc77445",                        [{"hovertemplate":"lon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.7822694,3.6840657,3.5436183,3.0341748,3.2595483,3.4940271,3.2797783,3.4884096,3.3341333,3.5471293,3.5844349,3.5287173,3.2479046,3.8459144,4.1253959,3.3459393,3.3629133,3.7540898,4.0639683,3.6717089,3.3223893,3.6450411,3.7700664,3.3673881,3.6682425,3.7074939,3.2538021,3.2579501,3.3633999,3.3508418,3.2584812,3.6565878,3.3046987,3.3544045,4.1168533,3.3176446,3.2555425,3.8529733,3.2071543,3.5271126,3.5482144,3.2611436,3.4843224,3

# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2251cef7458182884599ae09297263bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2251cef7458182884599ae09297263bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2251cef7458182884599ae09297263bd = L.map(
#                 &quot;map_2251cef7458182884599ae09297263bd&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15b435dbf0590be1f7b0a8cfb3aae9bc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15b435dbf0590be1f7b0a8cfb3aae9bc.addTo(map_2251cef7458182884599ae09297263bd);
#
#
#             var marker_b2973237f8354d2b6b420b6dcd46e45c = L.marker(
#                 [6.4724391, 3.7822694],
#                 {
# }
#             ).addTo(map_2251cef7458182884599ae09297263bd);
#
#
#         var popup_81dea6da6f86732dad8b68eeaf675d91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_796bec29b6dc0246de9befdf1799bf15 = $(`&lt;div id=&quot;html_796bec29b6dc0246de9befdf1799bf15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_81dea6da6f86732dad8b68eeaf675d91.setContent(html_796bec29b6dc0246de9befdf1799bf15);
#
#
#
#         marker_b2973237f8354d2b6b420b6dcd46e45c.bindPopup(popup_81dea6da6f86732dad8b68eeaf675d91)
#         ;
#
#
#
#
#             var marker_80ff93bbb662a14db5916295f416ef2b = L.marker(
#                 [6.4609044, 3.6840657],
#                 {
# }
#             ).addTo(map_2251cef7458182884599ae09297263bd);
#
#
#         var popup_7826d6116eb94f630ec9093c4a22530a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19119e89626ad29baf61437c28b9e8c4 = $(`&lt;div id=&quot;html_19119e89626ad29baf61437c28b9e8c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_7826d6116eb94f630ec9093c4a22530a.setContent(html_19119e89626ad29baf61437c28b9e8c4);
#
#
#
#         marker_80ff93bbb662a14db5916295f416ef2b.bindPopup(popup_7826d6116eb94f630ec9093c4a22530a)
#         ;
#
#
#
#
#             var marker_404d410d2fac2fa8e8dbb23a43878392 = L.marker(
#                 [6.59287, 3.5436183],
#                 {
# }
#             ).addTo(map_2251cef7458182884599ae09297263bd);
#
#
#         var popup_972e3c829f2c05d2dd3896165f56933f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb14cdad445c6b9e3cfe52b14edd4b12 = $(`&lt;div id=&quot;html_fb14cdad445c6b9e3cfe52b14edd4b12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_972e3c829f2c05d2dd3896165f56933f.setContent(html_fb14cdad445c6b9e3cfe52b14edd4b12);
#
#
#
#         marker_404d410d2fac2fa8e8dbb23a43878392.bindPopup(popup_972e3c829f2c05d2dd3896165f56933f)
#         ;
#
#
#
#
#             var marker_9c7bb3a74d588faeb6493f41e9e29071 = L.marker(
#                 [6.4633558, 3.0341748],
#                 {
# }
#             ).addTo(map_2251cef7458182884599ae09297263bd);
#
#
#         var popup_1bf24510fdfa52b55edbc39a03bbcbb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_183adb030584809ea09529f4f4d27061 = $(`&lt;div id=&quot;html_183adb030584809ea09529f4f4d27061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_1bf24510fdfa52b55edbc39a03bbcbb6.setContent(html_183adb030584809ea09529f4f4d27061);
#
#
#
#         marker_9c7bb3a74d588faeb6493f41e9e29071.bindPopup(popup_1bf24510fdfa52b55edbc39a03bbcbb6)
#         ;
#
#
#
#
#             var marker_b300f5448cd857314465b092eec2c4b4 = L.marker(
#                 [6.526905, 3.2595483],
#                 {
# }
#             ).addTo(map_2251cef7458182884599ae09297263bd);
#
#
#         var popup_3ba9a5762299544572909aee0f256ff8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44e81c2e7cfbc8b8c12869c738bc4eb1 = $(`&lt;div id=&quot;html_44e81c2e7cfbc8b8c12869c738bc4eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;name&lt;/div&gt;`)[0];
#                 popup_3ba9a5762299544572909aee0f256ff8.setContent(html_44e81c2e7cfbc8b8c12869c738bc4eb1);
#
#
#
#         marker_b300f5448cd857314465b092eec2c4b4.bindPopup(popup_3ba9a5762299544572909aee0f256ff8)
#         ;
#
#
#
#
#             var marker_2b9e18c59d4ba173f7e9e38f80c968fd = L.marke

# %%
bubble = folium.Map(location =[6.5244, 3.3792],
                       zoom_start =12,tiles ='cartodbpositron')
mc = MarkerCluster()
for idx, row in factories.iterrows():
    mc.add_child(Marker([row['lat'], row['lon']]))
bubble.add_child(mc)
bubble
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecedda58bd4e78e16075a42f9f0c7ee7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecedda58bd4e78e16075a42f9f0c7ee7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecedda58bd4e78e16075a42f9f0c7ee7 = L.map(
#                 &quot;map_ecedda58bd4e78e16075a42f9f0c7ee7&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1aad772df6d5bb927e315384a027a06d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1aad772df6d5bb927e315384a027a06d.addTo(map_ecedda58bd4e78e16075a42f9f0c7ee7);
#
#
#             var marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_1723ef345e071fa0dbfc8f8dd94d937a = L.marker(
#                 [6.4724391, 3.7822694],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_21de0057964f134e05bb9886950e3823 = L.marker(
#                 [6.4609044, 3.6840657],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_49ec51a75a5f04230175fd190c1ebcd2 = L.marker(
#                 [6.59287, 3.5436183],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_ac4a4921eda57d319b06e0bcfc0eb0d7 = L.marker(
#                 [6.4633558, 3.0341748],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_8ca8533ff6a7ad656ea34220be730674 = L.marker(
#                 [6.526905, 3.2595483],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_aca47d2b4be92437a7967decad6a976c = L.marker(
#                 [6.6786892, 3.4940271],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_3f59b27ff1fc9d21d6f38e636ba1fe73 = L.marker(
#                 [6.5280467, 3.2797783],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_44b27aae6cdf2af1e3cda6510794af4f = L.marker(
#                 [6.5861481, 3.4884096],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_e7366a8c86a4a3da8d4ad7aa1e72660e = L.marker(
#                 [6.6600383, 3.3341333],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_f5dcb5228dd94c089ace09764f015cc5 = L.marker(
#                 [6.6537608, 3.5471293],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_3dc81045472b32ec74aff21ed83acf6d = L.marker(
#                 [6.6570728, 3.5844349],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_b8d5af85d3e4fe14c8c3a9e11aba60e4 = L.marker(
#                 [6.6675921, 3.5287173],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_8d7e7efd3bb4f6be4118cea007f856cd = L.marker(
#                 [6.5207974, 3.2479046],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_9e0b6a9d089a368be646539bfc0c5b3a = L.marker(
#                 [6.475655, 3.8459144],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_5343174f44cd323fe2ea1dc4a0648d9c = L.marker(
#                 [6.4116961, 4.1253959],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_fa13a4c6b53f1353447ff22c5362ad45 = L.marker(
#                 [6.6224475, 3.3459393],
#                 {
# }
#             ).addTo(marker_cluster_37ae4b3aa02b1a7b1bf7e179a5ef0c78);
#
#
#             var marker_00d49206465033e

# %%
heat = folium.Map(location=[6.5244, 3.3792], tiles='cartodbpositron', zoom_start=10)
HeatMap(data=factories[['lat', 'lon']], radius=10).add_to(heat)
heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9837cf3018299e88df53780a6d235b35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9837cf3018299e88df53780a6d235b35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9837cf3018299e88df53780a6d235b35 = L.map(
#                 &quot;map_9837cf3018299e88df53780a6d235b35&quot;,
#                 {
#                     center: [6.5244, 3.3792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2be0062e836342099dc028858690502d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2be0062e836342099dc028858690502d.addTo(map_9837cf3018299e88df53780a6d235b35);
#
#
#             var heat_map_1f15ca6ca1755f24abb62eea2a1ccabd = L.heatLayer(
#                 [[6.4724391, 3.7822694], [6.4609044, 3.6840657], [6.59287, 3.5436183], [6.4633558, 3.0341748], [6.526905, 3.2595483], [6.6786892, 3.4940271], [6.5280467, 3.2797783], [6.5861481, 3.4884096], [6.6600383, 3.3341333], [6.6537608, 3.5471293], [6.6570728, 3.5844349], [6.6675921, 3.5287173], [6.5207974, 3.2479046], [6.475655, 3.8459144], [6.4116961, 4.1253959], [6.6224475, 3.3459393], [6.438055, 3.3629133], [6.4690936, 3.7540898], [6.4211283, 4.0639683], [6.4636307, 3.6717089], [6.473822, 3.3223893], [6.615114, 3.6450411], [6.4758176, 3.7700664], [6.61151, 3.3673881], [6.4652846, 3.6682425], [6.4636235, 3.7074939], [6.6281034, 3.2538021], [6.623906, 3.2579501], [6.4471279, 3.3633999], [6.6285321, 3.3508418], [6.5096881, 3.2584812], [6.5897372, 3.6565878], [6.5823762, 3.3046987], [6.5541234, 3.3544045], [6.4123717, 4.1168533], [6.4747587, 3.3176446], [6.613868, 3.2555425], [6.4801467, 3.8529733],