# %% [markdown]
# <a href="https://colab.research.google.com/github/MaddyMk05/VA_Open_Ended_Experiments/blob/main/Experiment_No_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Open-Ended Experiment 4: Visualization Redesign Challenge**
#
# **Title:** Redesign a Poor Visualization to Improve Clarity and Communication
#
# **Objective:**
#
# Students will analyze a poor or misleading chart (from a report, newspaper, blog, or social media), critique its weaknesses, and redesign it using Seaborn, Matplotlib, or Power BI/Tableau.
#
# **Task:**
# 1. Find or choose a bad data visualization (can be misleading axes, wrong chart type, poor color usage, cluttered info, etc.).
# 2. Explain the issues in the original chart.
# 3. Redesign the visualization for clarity, accuracy, and aesthetics.
# 4. Present a before-and-after comparison with explanation.
#
# **Expected Outcome:**
#
# A mini-report or presentation showing:
# - Original visualization
# - Redesigned version
# - Justification of improvements

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import geopandas as gpd

# %%
factories = gpd.read_file('/content/factoriesindustrial-sites.geojson')

# %%
factories = factories[['name', 'status', 'geometry']]
status_counts = factories['status'].value_counts()

# %%
#BAD PIE CHART
plt.figure(figsize=(6, 6))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title('Distribution of Factory Statuses in Lagos')
plt.axis('equal')
plt.show()

# %%
# Redesigned Visualization: Bar Chart
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(
    x=status_counts.index,
    y=status_counts.values,
    palette='viridis'
)
# Out:
# <ipython-input-10-20a6dca0574a>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='status'>
